# %%
import re

# %%
with open("/tmp/calibration_output.txt") as f:
    text = f.read()
print(text)
# Out:
# *** Added sample 1, p_x = 0.282, p_y = 0.317, p_size = 0.159, skew = 0.287
# *** Added sample 2, p_x = 0.279, p_y = 0.315, p_size = 0.159, skew = 0.086
# *** Added sample 3, p_x = 0.339, p_y = 0.314, p_size = 0.133, skew = 0.717
# *** Added sample 4, p_x = 0.578, p_y = 0.501, p_size = 0.241, skew = 0.219
# *** Added sample 5, p_x = 0.546, p_y = 0.327, p_size = 0.166, skew = 0.385
# *** Added sample 6, p_x = 0.527, p_y = 0.435, p_size = 0.198, skew = 0.012
# *** Added sample 7, p_x = 0.575, p_y = 0.341, p_size = 0.205, skew = 0.073
# *** Added sample 8, p_x = 0.663, p_y = 0.286, p_size = 0.210, skew = 0.135
# *** Added sample 9, p_x = 0.802, p_y = 0.246, p_size = 0.235, skew = 0.188
# *** Added sample 10, p_x = 0.698, p_y = 0.245, p_size = 0.207, skew = 0.279
# *** Added sample 11, p_x = 0.707, p_y = 0.156, p_size = 0.255, skew = 0.177
# *** Added sample 12, p_x = 0.718, p_y = 0.191, p_size = 0.340, skew = 0.256
# ...

# %%
re.search(r"Wrote calibration.*?\)", text).group(0)
# Out:
# "Wrote calibration data to', '/tmp/calibrationdata.tar.gz')"
